# %%
import requests
import time

commander_input = "Quandrix, The Proof"
# commander_input = "RANDOM"
# num_ramp = 10
# num_draw = 10
# num_removal = 10
year_filter = "(year>=1997 and year<2007)"
price_filter = ""
filler_price_filter="usd<50"
# commander_set_filter="set:KLD"
commander_set_filter=""
num_ramp = 15
num_draw = 5
num_removal = 10
enable_fetch = False
if commander_input == "RANDOM":
    num_ramp = 10
    num_draw = 10
    num_removal = 10

HEADERS = {
    "User-Agent": "deck-builder-bot/1.2",
    "Accept": "application/json"
}

def get_commander(name):
    url = "https://api.scryfall.com/cards/named"
    params = {
        "exact": name
    }

    r = requests.get(url, params=params, headers=HEADERS)
    r.raise_for_status()
    return r.json()


def fetch_all_cards(query):
    url = "https://api.scryfall.com/cards/search"
    params = {"q": query}
    print(query)
    cards = []
    card_index = 0
    while True:
        
        r = requests.get(url, params=params, headers=HEADERS)
        r.raise_for_status()
        data = r.json()
        card_index += len(data["data"]) 
        total_cards = data["total_cards"]
        percentage = float(card_index)/data["total_cards"] * 100
        print(f"current index {card_index}, total cards {total_cards}, percentage {percentage}")

        cards.extend(data["data"])

        if not data.get("has_more"):
            break

        # IMPORTANT: next_page already includes query params
        url = data["next_page"]
        params = None
        time.sleep(0.2) # dont want to get rate limited
    return cards

# %%
commander = ""
import random

if commander_input == "RANDOM":
    print("getting random commander")
    
    commander_list = fetch_all_cards((
        f"-is:playtest "
        f"f:commander "
        f"type:creature type:legendary "
        f"-is:gamechanger "
        f"-set:UNF -set:SUNF "
        f"-o:snow "
        f"{year_filter} "
        f"{price_filter} "
        f"{commander_set_filter} "
    ))
    commander = commander_list[random.randint(0,len(commander_list)-1)]
else:
    commander = get_commander(commander_input)

# %%
color_identity = commander["color_identity"]
print(commander['name'], color_identity)  # e.g. ['G', 'U', 'B', 'W']
def color_identity_query(ci):
    if not ci:
        return "ci=0"   # colorless commanders (Kozilek, etc.)
    return f"ci<={''.join(ci)}"
cid_string = color_identity_query(color_identity)
print(cid_string)
# Out:
# Quandrix, the Proof ['G', 'U']
# ci<=GU

# %%
QUERIES = {
#     "ramp" : f"usd<10 function:ramp {cid_string} -is:playtest -name:\"Sol Ring\" cmc<5 -type:land -set:UNF f:commander -is:gamechanger -o:snow",
#     "draw" : f"usd<10 function:draw {cid_string} -is:playtest cmc<5 -type:land -set:UNF f:commander -is:gamechanger -o:snow",
#     "removal" : f"usd<10 function:removal {cid_string} -is:playtest -type:land -set:UNF f:commander -is:gamechanger -o:snow"
    "ramp" : f"function:ramp {cid_string} -is:gamechanger -is:playtest -name:\"Sol Ring\" cmc<5 -type:land -set:UNF f:commander -is:gamechanger -o:snow {year_filter} {price_filter}",
    "draw" : f"function:draw {cid_string} -is:gamechanger -is:playtest cmc<5 -type:land -set:UNF f:commander -is:gamechanger -o:snow {year_filter} {price_filter}",
    "removal" : f"function:removal {cid_string} -is:gamechanger -is:playtest -type:land -set:UNF f:commander -is:gamechanger -o:snow {year_filter} {price_filter}"
}

ramp_cards    = fetch_all_cards(QUERIES["ramp"])
draw_cards    = fetch_all_cards(QUERIES["draw"])
removal_cards = fetch_all_cards(QUERIES["removal"])
# Out:
# function:ramp ci<=GU -is:gamechanger -is:playtest -name:"Sol Ring" cmc<5 -type:land -set:UNF f:commander -is:gamechanger -o:snow (year>=1997 and year<2007)
# current index 159, total cards 159, percentage 100.0
# function:draw ci<=GU -is:gamechanger -is:playtest cmc<5 -type:land -set:UNF f:commander -is:gamechanger -o:snow (year>=1997 and year<2007)
# current index 175, total cards 296, percentage 59.12162162162162
# current index 296, total cards 296, percentage 100.0
# function:removal ci<=GU -is:gamechanger -is:playtest -type:land -set:UNF f:commander -is:gamechanger -o:snow (year>=1997 and year<2007)
# current index 175, total cards 377, percentage 46.41909814323608
# current index 350, total cards 377, percentage 92.83819628647215
# current index 377, total cards 377, percentage 100.0

# %%
import random

def pick_random(cards, n):
    if len(cards) < n:
        raise ValueError(f"Not enough cards to sample {n}")
    return random.sample(cards, n)

def reroll_until_disjoint(ramp_cards, draw_cards, removal_cards,
                          num_ramp, num_draw, num_removal,
                          max_attempts=50):

    for attempt_number in range(max_attempts):
        chosen_ramp    = pick_random(ramp_cards, num_ramp)
        chosen_draw    = pick_random(draw_cards, num_draw)
        chosen_removal = pick_random(removal_cards, num_removal)

        names = (
            [c["name"] for c in chosen_ramp] +
            [c["name"] for c in chosen_draw] +
            [c["name"] for c in chosen_removal]
        )

        if len(names) == len(set(names)):
            return chosen_ramp, chosen_draw, chosen_removal
        print(f"Rerolling, attempt {attempt_number}")

    raise RuntimeError("Could not find disjoint role assignment")


chosen_ramp, chosen_draw, chosen_removal = reroll_until_disjoint(ramp_cards, draw_cards, removal_cards, num_ramp, num_draw, num_removal)

# %%
COLOR_TO_BASIC = {
    "W": "Plains",
    "U": "Island",
    "B": "Swamp",
    "R": "Mountain",
    "G": "Forest"
}

def get_basic_lands(color_identity, total_basics=16):
    if not color_identity:
        return ["Wastes"] * total_basics

    basics = []
    per_color = total_basics // len(color_identity)
    remainder = total_basics % len(color_identity)

    for c in color_identity:
        basics.extend([COLOR_TO_BASIC[c]] * per_color)

    for i in range(remainder):
        basics.append(COLOR_TO_BASIC[color_identity[i]])

    return basics

def multicolor_land_query(ci):
    return (
        f"type:land -type:basic legal:commander -is:gamechanger -is:playtest "
        f"ci<={''.join(ci)} "
        f"o:/add .*[{''.join(ci)}].*[{''.join(ci)}]/"
    )


FETCH_QUERY = (
    "type:land legal:commander "
    "(o:search or o:sacrifice) -is:gamechanger -is:playtest "
    "-o:add"
)

multicolor_lands = fetch_all_cards(multicolor_land_query(color_identity))
# since we dont have consistent dual lands, I decided to disable for now
fetch_lands = []
if enable_fetch:
    fetch_lands = fetch_all_cards(FETCH_QUERY)
# Out:
# type:land -type:basic legal:commander -is:gamechanger -is:playtest ci<=GU o:/add .*[GU].*[GU]/
# current index 89, total cards 89, percentage 100.0

# %%
import random
print('getting land base')
def pick(cards, n):
    return random.sample(cards, min(n, len(cards)))


chosen_fetches    = pick(fetch_lands, 10)

land_base = []
basic_lands = []
chosen_multicolor = []
if len(color_identity) == 1:
    print('getting only basics')
    if enable_fetch:
        basic_lands       = get_basic_lands(color_identity, 28)
    else:
        basic_lands       = get_basic_lands(color_identity, 38)
elif len(color_identity) == 2:
    print('getting multi lands and basics')
    if enable_fetch:
        basic_lands       = get_basic_lands(color_identity, 16)
        chosen_multicolor = pick(multicolor_lands, 12)
    else:
        basic_lands       = get_basic_lands(color_identity, 21)
        chosen_multicolor = pick(multicolor_lands, 17)
elif len(color_identity) == 3:
    print('getting multi lands and basics')
    if enable_fetch:
        basic_lands       = get_basic_lands(color_identity, 8)
        chosen_multicolor = pick(multicolor_lands, 20)
    else:
        basic_lands       = get_basic_lands(color_identity, 13)
        chosen_multicolor = pick(multicolor_lands, 25)
elif len(color_identity) >= 4:
    print('getting multi lands and basics')
    if enable_fetch:
        basic_lands       = get_basic_lands(color_identity, 4)
        chosen_multicolor = pick(multicolor_lands, 24)
    else:
        basic_lands       = get_basic_lands(color_identity, 9)
        chosen_multicolor = pick(multicolor_lands, 29)

# Basics (names only)
for b in basic_lands:
    land_base.append({"name": b})

# Multicolor lands
land_base.extend(chosen_multicolor)

# Fetch lands
land_base.extend(chosen_fetches)
# Out:
# getting land base
# getting multi lands and basics

# %%
SOL_RING = "Sol Ring"

# %%
def random_filler_query(ci):
    ci_filter = f"ci<={''.join(ci)}" if ci else "ci=0"
    # one printing of Red Herring is illegal 
    return (
        f"legal:commander "
        f"{ci_filter} "
        f"-type:land "
        f"-is:funny "
        f"-set:UNF "
        f"-set:SUNF "
        f"-o:snow "
        f"-is:playtest "
        f"-type:conspiracy "
        f"-type:emblem "
        f"-name:\"Sol Ring\" "
        f"-name:\"Red Herring\" "
        f"-is:gamechanger "
        f"{year_filter} "
        f"{filler_price_filter} "
    )

print("fetching filler cards")
filler_cards = fetch_all_cards(random_filler_query(color_identity))
unique_by_name = {}
for card in filler_cards:
    unique_by_name.setdefault(card["name"], card)

unique_cards = list(unique_by_name.values())

random_cards = random.sample(
    unique_cards,
    min(30, len(unique_cards))
)
# Out:
# fetching filler cards
# legal:commander ci<=GU -type:land -is:funny -set:UNF -set:SUNF -o:snow -is:playtest -type:conspiracy -type:emblem -name:"Sol Ring" -name:"Red Herring" -is:gamechanger (year>=1997 and year<2007) usd<50
# current index 175, total cards 2926, percentage 5.980861244019139
# current index 350, total cards 2926, percentage 11.961722488038278
# current index 525, total cards 2926, percentage 17.942583732057415
# current index 700, total cards 2926, percentage 23.923444976076556
# current index 875, total cards 2926, percentage 29.904306220095695
# current index 1050, total cards 2926, percentage 35.88516746411483
# current index 1225, total cards 2926, percentage 41.866028708133975
# current index 1400, total cards 2926, percentage 47.84688995215311
# current index 1575, total cards 2926, percentage 53.827751196172244
# current index 1750, total cards 2926, percentage 59.80861244019139
# current index 1925, total cards 2926, percentage 65.78947368421053
# current index 2100, total cards 2926, percentage 71.77033492822966
# current index 2275, total cards 2926, percentage 77.75119617224881
# current index 2450, total cards 2926, percentage 83.73205741626795
# current index 2625, total cards 2926, percentage 89.71291866028707
# current index 2800, total cards 2926, percentage 95.69377990430623
# current index 2926, total cards 2926, percentage 100.0

# %%
deck = []
deck.append(commander)
# Core spells
deck.extend(chosen_ramp)
deck.extend(chosen_draw)
deck.extend(chosen_removal)

# Lands
deck.extend(land_base)

# Random filler
deck.extend(random_cards)

# Sol Ring
deck.append({"name": SOL_RING})

# %%
from collections import Counter

counts = Counter(c["name"] for c in deck)

for name, count in sorted(counts.items()):
    print(f"{count} {name}")
# Out:
# 1 Adarkar Windform
# 1 Animate Land
# 1 Aspect of Wolf
# 1 Barkhide Mauler
# 1 Binding Grasp
# 1 Birds of Paradise
# 1 Bottled Cloister
# 1 Branch of Vitu-Ghazi
# 1 Brotherhood Headquarters
# 1 Carpet of Flowers
# 1 Centaur Garden
# 1 Cephalid Coliseum
# 1 Chlorophant
# 1 Drowner of Truth // Drowned Jungle
# 1 Echoing Truth
# 1 Eladamri's Vineyard
# 1 Erhnam Djinn
# 1 Excavation
# 1 Fallow Earth
# 11 Forest
# 1 Gemstone Caverns
# 1 Grafted Wargear
# 1 Grand Coliseum
# 1 Harrow
# 1 Harvester Druid
# 1 Haven of the Spirit Dragon
# 1 Horizon of Progress
# 1 Hypergenesis
# 10 Island
# 1 Jinxed Idol
# 1 Lifegift
# 2 Llanowar Druid
# 1 Magnetic Flux
# 1 Mana Prism
# 1 Merfolk Traders
# 1 Mimeofacture
# 1 Mistform Mask
# 1 Multani's Harmony
# 1 Nantuko Calmer
# 1 Ophidian
# 1 Overflowing Basin
# 1 Overgrowth
# 1 Powder Keg
# 1 Primal Boost
# 1 Psionic Blast
# 1 Quandrix, the Proof
# 1 Red Cliffs Armada
# 1 Seahunter
# 1 Serum Powder
# 1 Shifting Sliver
# 1 Silverglade Elemental
# 1 Simic Signet
# 1 Sky Diamond
# 1 Sol Ring
# 1 Sorcerous Sight
# 1 Storm Cauldron
# 1 Study Hall
# 1 Teferi's Isle
# 1 Tenza, Godo's Maul
# 1 The Hive
# 1 Thornwood Falls
# 1 Thoughtbind
# 1 Thresher Beast
# 1 Tidespout Tyrant
# 1 Time Stop
# 1 Traveler's Cloak
# 1 Uktabi Wildcats
# 1 Undiscovered Paradise
# 1 Unstable Mutation
# 1 Uproot
# 1 Urza's Bauble
# 1 Urza's Power Plant
# 1 Urza's Workshop
# 1 Vedalken Dismisser
# 1 Verdant Eidolon
# 1 Verdigris
# 1 Veteran Explorer
# 1 Vine Trellis
# 1 Viridian Longbow
# 1 Woodland Stream

# %%
print(f"\nchosen_ramp {num_ramp}\n########################")
for card in chosen_ramp:
    print(card['name'])
print(f"\nchosen_draw {num_draw}\n########################")
for card in chosen_draw:
    print(card['name'])
print(f"\nchosen_removal {num_removal}\n########################")

for card in chosen_removal:
    print(card['name'])
# Out:
# chosen_ramp 15
# ########################
# Hypergenesis
# Veteran Explorer
# Eladamri's Vineyard
# Verdant Eidolon
# Harvester Druid
# Llanowar Druid
# Overgrowth
# Simic Signet
# Vine Trellis
# Carpet of Flowers
# Harrow
# Sky Diamond
# Serum Powder
# Multani's Harmony
# Birds of Paradise
#
# chosen_draw 5
# ########################
# Urza's Bauble
# Primal Boost
# Traveler's Cloak
# Excavation
# Ophidian
#
# chosen_removal 10
# ########################
# Thresher Beast
# Verdigris
# Storm Cauldron
# Uproot
# Powder Keg
# Fallow Earth
# Viridian Longbow
# Echoing Truth
# Unstable Mutation
# Psionic Blast
