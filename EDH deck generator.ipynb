# %%
import requests
import time

# commander_input = "sheoldred the apocalypse"
commander_input = "Queza, Augur of Agonies"
# num_ramp = 10
# num_draw = 10
# num_removal = 10
num_ramp = 3
num_draw = 20
num_removal = 7

HEADERS = {
    "User-Agent": "deck-builder-bot/1.0",
    "Accept": "application/json"
}

def get_commander(name):
    url = "https://api.scryfall.com/cards/named"
    params = {
        "exact": name
    }

    r = requests.get(url, params=params, headers=HEADERS)
    r.raise_for_status()
    return r.json()


def fetch_all_cards(query):
    url = "https://api.scryfall.com/cards/search"
    params = {"q": query}
    print(query)
    cards = []
    card_index = 0
    while True:
        
        r = requests.get(url, params=params, headers=HEADERS)
        r.raise_for_status()
        data = r.json()
        card_index += len(data["data"]) 
        total_cards = data["total_cards"]
        percentage = float(card_index)/data["total_cards"] * 100
        print(f"current index {card_index}, total cards {total_cards}, percentage {percentage}")

        cards.extend(data["data"])

        if not data.get("has_more"):
            break

        # IMPORTANT: next_page already includes query params
        url = data["next_page"]
        params = None
        time.sleep(0.2) # dont want to get rate limited
    return cards

# %%
commander = get_commander(commander_input)

# %%
color_identity = commander["color_identity"]
print(commander['name'], color_identity)  # e.g. ['G', 'U', 'B', 'W']
def color_identity_query(ci):
    if not ci:
        return "ci=0"   # colorless commanders (Kozilek, etc.)
    return f"ci<={''.join(ci)}"
cid_string = color_identity_query(color_identity)
print(cid_string)
# Out:
# Queza, Augur of Agonies ['B', 'U', 'W']
# ci<=BUW

# %%
QUERIES = {
    "ramp" : f"usd<5 function:ramp {cid_string} cmc<5 -type:land -set:UNF f:commander -is:gamechanger -o:snow",
    "draw" : f"usd<5 function:draw {cid_string} cmc<5 -type:land -set:UNF f:commander -is:gamechanger -o:snow",
    "removal" : f"usd<5 function:removal {cid_string} -type:land -set:UNF f:commander -is:gamechanger -o:snow"
}

ramp_cards    = fetch_all_cards(QUERIES["ramp"])
draw_cards    = fetch_all_cards(QUERIES["draw"])
removal_cards = fetch_all_cards(QUERIES["removal"])
# Out:
# usd<5 function:ramp ci<=BUW cmc<5 -type:land -set:UNF f:commander -is:gamechanger -o:snow
# current index 175, total cards 449, percentage 38.97550111358575
# current index 350, total cards 449, percentage 77.9510022271715
# current index 449, total cards 449, percentage 100.0
# usd<5 function:draw ci<=BUW cmc<5 -type:land -set:UNF f:commander -is:gamechanger -o:snow
# current index 175, total cards 1747, percentage 10.01717229536348
# current index 350, total cards 1747, percentage 20.03434459072696
# current index 525, total cards 1747, percentage 30.05151688609044
# current index 700, total cards 1747, percentage 40.06868918145392
# current index 875, total cards 1747, percentage 50.085861476817406
# current index 1050, total cards 1747, percentage 60.10303377218088
# current index 1225, total cards 1747, percentage 70.12020606754436
# current index 1400, total cards 1747, percentage 80.13737836290784
# current index 1575, total cards 1747, percentage 90.15455065827133
# current index 1747, total cards 1747, percentage 100.0
# usd<5 function:removal ci<=BUW -type:land -set:UNF f:commander -is:gamechanger -o:snow
# current index 175, total cards 2843, percentage 6.155469574393246
# current index 350, total cards 2843, percentage 12.310939148786492
# current index 525, total cards 2843, percentage 18.46640872317974
# current index 700, total cards 2843, percentage 24.621878297572984
# current index 875, total cards 2843, percentage 30.77734787196623
# current index 1050, total cards 2843, percentage 36.93281744635948
# current index 1225, total cards 2843, percentage 43.08828702075272
# current index 1400, total cards 2843, percentage 49.24375659514597
# current index 1575, total cards 2843, percentage 55.39922616953922
# current index 1750, total cards 2843, percentage 61.55469574393246
# current index 1925, total cards 2843, percentage 67.7101653183257
# current index 2100, total cards 2843, percentage 73.86563489271896
# current index 2275, total cards 2843, percentage 80.02110446711221
# current index 2450, total cards 2843, percentage 86.17657404150545
# current index 2625, total cards 2843, percentage 92.3320436158987
# current index 2800, total cards 2843, percentage 98.48751319029193
# current index 2843, total cards 2843, percentage 100.0

# %%
import random

def pick_random(cards, n):
    if len(cards) < n:
        raise ValueError(f"Not enough cards to sample {n}")
    return random.sample(cards, n)



chosen_ramp    = pick_random(ramp_cards, num_ramp)
chosen_draw    = pick_random(draw_cards, num_draw)
chosen_removal = pick_random(removal_cards, num_removal)

# %%
COLOR_TO_BASIC = {
    "W": "Plains",
    "U": "Island",
    "B": "Swamp",
    "R": "Mountain",
    "G": "Forest"
}

def get_basic_lands(color_identity, total_basics=16):
    if not color_identity:
        return ["Wastes"] * total_basics

    basics = []
    per_color = total_basics // len(color_identity)
    remainder = total_basics % len(color_identity)

    for c in color_identity:
        basics.extend([COLOR_TO_BASIC[c]] * per_color)

    for i in range(remainder):
        basics.append(COLOR_TO_BASIC[color_identity[i]])

    return basics

def multicolor_land_query(ci):
    return (
        f"type:land -type:basic legal:commander -is:gamechanger "
        f"ci<={''.join(ci)} "
        f"o:/add .*[{''.join(ci)}].*[{''.join(ci)}]/"
    )


FETCH_QUERY = (
    "type:land legal:commander "
    "(o:search or o:sacrifice) -is:gamechanger "
    "-o:add"
)

multicolor_lands = fetch_all_cards(multicolor_land_query(color_identity))
fetch_lands = fetch_all_cards(FETCH_QUERY)
# Out:
# type:land -type:basic legal:commander -is:gamechanger ci<=BUW o:/add .*[BUW].*[BUW]/
# current index 167, total cards 167, percentage 100.0
# type:land legal:commander (o:search or o:sacrifice) -is:gamechanger -o:add
# current index 31, total cards 31, percentage 100.0

# %%
import random
print('getting land base')
def pick(cards, n):
    return random.sample(cards, min(n, len(cards)))


chosen_fetches    = pick(fetch_lands, 10)

land_base = []
basic_lands = []
chosen_multicolor = []
if len(color_identity) == 1:
    print('getting only basics')
    basic_lands       = get_basic_lands(color_identity, 28)
elif len(color_identity) == 2:
    print('getting multi lands and basics')
    basic_lands       = get_basic_lands(color_identity, 16)
    chosen_multicolor = pick(multicolor_lands, 12)
elif len(color_identity) == 3:
    print('getting multi lands and basics')
    basic_lands       = get_basic_lands(color_identity, 8)
    chosen_multicolor = pick(multicolor_lands, 20)
elif len(color_identity) >= 4:
    print('getting multi lands and basics')
    basic_lands       = get_basic_lands(color_identity, 4)
    chosen_multicolor = pick(multicolor_lands, 24)

# Basics (names only)
for b in basic_lands:
    land_base.append({"name": b})

# Multicolor lands
land_base.extend(chosen_multicolor)

# Fetch lands
land_base.extend(chosen_fetches)
# Out:
# getting land base
# getting multi lands and basics

# %%
SOL_RING = "Sol Ring"

# %%
def random_filler_query(ci):
    ci_filter = f"ci<={''.join(ci)}" if ci else "ci=0"

    return (
        f"legal:commander "
        f"{ci_filter} "
        f"-type:land "
        f"-is:funny "
        f"-set:UNF "
        f"-o:snow "
        f"-type:conspiracy "
        f"-type:emblem "
        f"-name:\"Sol Ring\" "
        f"usd<=1"
    )

print("fetching filler cards")
filler_cards = fetch_all_cards(random_filler_query(color_identity))
random_cards = random.sample(filler_cards, min(30, len(filler_cards)))
# Out:
# fetching filler cards
# legal:commander ci<=BUW -type:land -is:funny -set:UNF -o:snow -type:conspiracy -type:emblem -name:"Sol Ring" usd<=1
# current index 175, total cards 14094, percentage 1.2416631190577552
# current index 350, total cards 14094, percentage 2.4833262381155103
# current index 525, total cards 14094, percentage 3.7249893571732655
# current index 700, total cards 14094, percentage 4.966652476231021
# current index 875, total cards 14094, percentage 6.208315595288775
# current index 1050, total cards 14094, percentage 7.449978714346531
# current index 1225, total cards 14094, percentage 8.691641833404287
# current index 1400, total cards 14094, percentage 9.933304952462041
# current index 1575, total cards 14094, percentage 11.174968071519796
# current index 1750, total cards 14094, percentage 12.41663119057755
# current index 1925, total cards 14094, percentage 13.658294309635306
# current index 2100, total cards 14094, percentage 14.899957428693062
# current index 2275, total cards 14094, percentage 16.141620547750815
# current index 2450, total cards 14094, percentage 17.383283666808573
# current index 2625, total cards 14094, percentage 18.624946785866324
# current index 2800, total cards 14094, percentage 19.866609904924083
# current index 2975, total cards 14094, percentage 21.108273023981834
# current index 3150, total cards 14094, percentage 22.349936143039592
# current index 3325, total cards 14094, percentage 23.591599262097347
# current index 3500, total cards 14094, percentage 24.8332623811551
# current index 3675, total cards 14094, percentage 26.07492550021286
# current index 3850, total cards 14094, percentage 27.31658861927061
# current index 4025, total cards 14094, percentage 28.558251738328366
# current index 4200, total cards 14094, percentage 29.799914857386124
# current index 4375, total cards 14094, percentage 31.04157797644388
# current index 4550, total cards 14094, percentage 32.28324109550163
# current index 4725, total cards 14094, percentage 33.524904214559385
# current index 4900, total cards 14094, percentage 34.76656733361715
# current index 5075, total cards 14094, percentage 36.0082304526749
# current index 5250, total cards 14094, percentage 37.24989357173265
# current index 5425, total cards 14094, percentage 38.491556690790404
# current index 5600, total cards 14094, percentage 39.733219809848165
# current index 5775, total cards 14094, percentage 40.97488292890591
# current index 5950, total cards 14094, percentage 42.21654604796367
# current index 6125, total cards 14094, percentage 43.45820916702143
# current index 6300, total cards 14094, percentage 44.699872286079184
# current index 6475, total cards 14094, percentage 45.94153540513693
# current index 6650, total cards 14094, percentage 47.183198524194694
# current index 6825, total cards 14094, percentage 48.42486164325245
# current index 7000, total cards 14094, percentage 49.6665247623102
# current index 7175, total cards 14094, percentage 50.90818788136796
# current index 7350, total cards 14094, percentage 52.14985100042572
# current index 7525, total cards 14094, percentage 53.39151411948346
# current index 7700, total cards 14094, percentage 54.63317723854122
# current index 7875, total cards 14094, percentage 55.87484035759898
# current index 8050, total cards 14094, percentage 57.11650347665673
# current index 8225, total cards 14094, percentage 58.358166595714486
# current index 8400, total cards 14094, percentage 59.59982971477225
# current index 8575, total cards 14094, percentage 60.84149283383
# current index 8750, total cards 14094, percentage 62.08315595288776
# current index 8925, total cards 14094, percentage 63.324819071945505
# current index 9100, total cards 14094, percentage 64.56648219100326
# current index 9275, total cards 14094, percentage 65.80814531006102
# current index 9450, total cards 14094, percentage 67.04980842911877
# current index 9625, total cards 14094, percentage 68.29147154817653
# current index 9800, total cards 14094, percentage 69.5331346672343
# current index 9975, total cards 14094, percentage 70.77479778629204
# current index 10150, total cards 14094, percentage 72.0164609053498
# current index 10325, total cards 14094, percentage 73.25812402440755
# current index 10500, total cards 14094, percentage 74.4997871434653
# current index 10675, total cards 14094, percentage 75.74145026252306
# current index 10850, total cards 14094, percentage 76.98311338158081
# current index 11025, total cards 14094, percentage 78.22477650063857
# current index 11200, total cards 14094, percentage 79.46643961969633
# current index 11375, total cards 14094, percentage 80.70810273875408
# current index 11550, total cards 14094, percentage 81.94976585781183
# current index 11725, total cards 14094, percentage 83.19142897686959
# current index 11900, total cards 14094, percentage 84.43309209592734
# current index 12075, total cards 14094, percentage 85.6747552149851
# current index 12250, total cards 14094, percentage 86.91641833404286
# current index 12425, total cards 14094, percentage 88.1580814531006
# current index 12600, total cards 14094, percentage 89.39974457215837
# current index 12775, total cards 14094, percentage 90.64140769121613
# current index 12950, total cards 14094, percentage 91.88307081027386
# current index 13125, total cards 14094, percentage 93.12473392933163
# current index 13300, total cards 14094, percentage 94.36639704838939
# current index 13475, total cards 14094, percentage 95.60806016744714
# current index 13650, total cards 14094, percentage 96.8497232865049
# current index 13825, total cards 14094, percentage 98.09138640556266
# current index 14000, total cards 14094, percentage 99.3330495246204
# current index 14094, total cards 14094, percentage 100.0

# %%
deck = []
deck.append(commander)
# Core spells
deck.extend(chosen_ramp)
deck.extend(chosen_draw)
deck.extend(chosen_removal)

# Lands
deck.extend(land_base)

# Random filler
deck.extend(random_cards)

# Sol Ring
deck.append({"name": SOL_RING})

# %%
from collections import Counter

counts = Counter(c["name"] for c in deck)

for name, count in sorted(counts.items()):
    print(f"{count} {name}")
# Out:
# 1 Abstruse Interference
# 1 Adaptive Shimmerer
# 1 Aesthir Glider
# 1 Alley Assailant
# 1 Amass the Components
# 1 Arcane Flight
# 1 Arcane Sanctum
# 1 Arid Mesa
# 1 Barrin's Codex
# 1 Basal Sliver
# 1 Battlefield Thaumaturge
# 1 Boneclad Necromancer
# 1 Boreal Shelf
# 1 Brokers Hideout
# 1 Cabal Pit
# 1 Cabal Trainee
# 1 Cabaretti Courtyard
# 1 Cactus Preserve
# 1 Call the Cavalry
# 1 Chant of Vitu-Ghazi
# 1 Circle of Affliction
# 1 Clairvoyance
# 1 Clan Crafter
# 1 Cloudpost
# 1 Combat Tutorial
# 1 Crystalline Crawler
# 1 Dark Depths
# 1 Darkblade Agent
# 1 Devouring Deep
# 1 Devouring Light
# 1 Douse in Gloom
# 1 Entrapment Maneuver
# 1 Exultant Cultist
# 1 Eye of Ugin
# 1 Fetid Heath
# 1 Fortified Beachhead
# 1 Goldmire Bridge
# 1 Great Hall of the Citadel
# 1 Gurgling Anointer
# 1 Inspiring Roar
# 3 Island
# 1 Katara, Bending Prodigy
# 1 Lay Down Arms
# 1 Leaden Fists
# 1 Lilypad Village
# 1 Mage-Ring Network
# 1 Malcolm, Alluring Scoundrel
# 1 Marsh Flats
# 1 Messenger Hawk
# 1 Mischievous Catgeist // Catlike Curiosity
# 1 Mistvault Bridge
# 1 Mystic Gate
# 1 Nykthos, Shrine to Nyx
# 1 Oblivion's Hunger
# 1 Obscura Storefront
# 1 Ordeal of Thassa
# 1 Palladium Myr
# 1 Phyrexian Tower
# 1 Plague Stinger
# 2 Plains
# 1 Popular Egotist
# 1 Purple-Crystal Crab
# 1 Qilin's Blessing
# 1 Queza, Augur of Agonies
# 1 Rejoin the Fight
# 1 Reverse the Sands
# 1 Rootwater Depths
# 1 Rousing of Souls
# 1 Sage of Lat-Nam
# 1 Scalding Tarn
# 1 Sea God's Revenge
# 1 Sea of Clouds
# 1 Senate Guildmage
# 1 Sengir Connoisseur
# 1 Septic Rats
# 1 Shadowbane
# 1 Shamble Back
# 1 Shambling Swarm
# 1 Silverquill Campus
# 1 Skybridge Towers
# 1 Smothering Abomination
# 1 Sol Ring
# 1 Starting Column
# 1 Strength of Isolation
# 3 Swamp
# 1 Tainted Indulgence
# 1 Thawing Glaciers
# 1 Time Ebb
# 1 Tome of Legends
# 1 Urza's Mine
# 1 Urza's Ruinous Blast
# 1 Vanish into Eternity
# 1 Windswept Heath
# 1 Yuriko, the Tiger's Shadow
# 1 Zero Point Ballad
